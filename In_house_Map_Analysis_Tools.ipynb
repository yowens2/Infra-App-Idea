# %% [markdown]
# <a href="https://colab.research.google.com/github/yowens2/common/blob/main/In_house_Map_Analysis_Tools.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a href="https://githubtocolab.com/giswqs/geemap/blob/master/examples/notebooks/geopandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab"/></a>
#
# Uncomment the following line to install [geemap](https://geemap.org) if needed.

# %% [markdown]
# # **The Benefit of using Map Data, to Enahnce SAP Data**
#
# 💦With the use of Python on the boom being adopted, in the Analaytics Acadmey, Telling Stories through Data is even more important to insure, that the data we provide is relatable and beliavble.
#
# By using Python (Geemaps) you are able to leverage the analytical capability of map data, stored in various formats, sh, json, geojson to list a few.
#
# This is my journey in understanding geo spatial data, and linking it to our Asset Base, by using various analytical techniques. To give a user a visual representation of the region we serve enviromental and social prosperity.
# 💦

# %%
# !pip install geemap

# %%
# !pip install geopandas

# %%
import os
import geemap
import pandas as pd
import geopandas as gpd

# %%
geemap.update_package()

# %% [markdown]
# ## **Creating** an **interactive map** and activating *popular geospatail analysis tool*

# %%
Map = geemap.Map()
Map
# Out:
# Map(center=[20, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], widget=HBox(children=(Togg…
# Downloading WhiteboxTools pre-compiled binary for first time use ...
# Decompressing WhiteboxTools_linux_amd64.zip ...
# WhiteboxTools package directory: /usr/local/lib/python3.7/dist-packages/whitebox
# Downloading testdata ...
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     754                 if 'buffer_paths' in data:
#     755                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 756                 self.set_state(state)
#     757
#     758         # Handle a state request.
#
# /usr/local/lib/python3.7/dist-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     623                     from_json = self.trait_metadata(name, 'from_json',
#     624                                                     self._trait_from_json)
# --> 625                     self.set_trait(name, from_json(sync_data[name], self))
#     626
#     627     def send(self, content, buffers=None):
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in set_trait(self, name, value)
#    1436             self._trait_notifiers[name] = {type: nlist}
#    1437         else:
# -> 1438             if type not in self._trait_notifiers[name]:
#    1439                 nlist = []
#    1440                 self._trait_notifiers[name][type] = nlist
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in set(self, obj, value)
#     578                 self.metadata = kwargs
#     579         else:
# --> 580             self.metadata = self.metadata.copy()
#     581         if config is not None:
#     582             self.metadata["config"] = config
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in _validate(self, obj, value)
#     610         This method is registered to HasTraits classes during ``class_init``
#     611         in the same way that dynamic defaults defined by ``@default`` are.
# --> 612         """
#     613         if self.default_value is not Undefined:
#     614             return self.default_value
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in validate(self, obj, value)
#    2188 class Any(TraitType):
#    2189     """A trait which allows any value."""
# -> 2190
#    2191     default_value: t.Optional[t.Any] = None
#    2192     allow_none = True
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in error(self, obj, value, error, info)
#     690         try:
#     691             old_value = obj._trait_values[self.name]
# --> 692         except KeyError:
#     693             old_value = self.default_value
#     694
#
# TraitError: The 'value' trait of a Label instance expected a unicode string, not the int 1.
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     754                 if 'buffer_paths' in data:
#     755                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 756                 self.set_state(state)
#     757
#     758         # Handle a state request.
#
# /usr/local/lib/python3.7/dist-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     623                     from_json = self.trait_metadata(name, 'from_json',
#     624                                                     self._trait_from_json)
# --> 625                     self.set_trait(name, from_json(sync_data[name], self))
#     626
#     627     def send(self, content, buffers=None):
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in set_trait(self, name, value)
#    1436             self._trait_notifiers[name] = {type: nlist}
#    1437         else:
# -> 1438             if type not in self._trait_notifiers[name]:
#    1439                 nlist = []
#    1440                 self._trait_notifiers[name][type] = nlist
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in set(self, obj, value)
#     578                 self.metadata = kwargs
#     579         else:
# --> 580             self.metadata = self.metadata.copy()
#     581         if config is not None:
#     582             self.metadata["config"] = config
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in _validate(self, obj, value)
#     610         This method is registered to HasTraits classes during ``class_init``
#     611         in the same way that dynamic defaults defined by ``@default`` are.
# --> 612         """
#     613         if self.default_value is not Undefined:
#     614             return self.default_value
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in validate(self, obj, value)
#    2188 class Any(TraitType):
#    2189     """A trait which allows any value."""
# -> 2190
#    2191     default_value: t.Optional[t.Any] = None
#    2192     allow_none = True
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in error(self, obj, value, error, info)
#     690         try:
#     691             old_value = obj._trait_values[self.name]
# --> 692         except KeyError:
#     693             old_value = self.default_value
#     694
#
# TraitError: The 'value' trait of a Label instance expected a unicode string, not the int 1.
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     754                 if 'buffer_paths' in data:
#     755                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 756                 self.set_state(state)
#     757
#     758         # Handle a state request.
#
# /usr/local/lib/python3.7/dist-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     623                     from_json = self.trait_metadata(name, 'from_json',
#     624                                                     self._trait_from_json)
# --> 625                     self.set_trait(name, from_json(sync_data[name], self))
#     626
#     627     def send(self, content, buffers=None):
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in set_trait(self, name, value)
#    1436             self._trait_notifiers[name] = {type: nlist}
#    1437         else:
# -> 1438             if type not in self._trait_notifiers[name]:
#    1439                 nlist = []
#    1440                 self._trait_notifiers[name][type] = nlist
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in set(self, obj, value)
#     578                 self.metadata = kwargs
#     579         else:
# --> 580             self.metadata = self.metadata.copy()
#     581         if config is not None:
#     582             self.metadata["config"] = config
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in _validate(self, obj, value)
#     610         This method is registered to HasTraits classes during ``class_init``
#     611         in the same way that dynamic defaults defined by ``@default`` are.
# --> 612         """
#     613         if self.default_value is not Undefined:
#     614             return self.default_value
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in validate(self, obj, value)
#    2188 class Any(TraitType):
#    2189     """A trait which allows any value."""
# -> 2190
#    2191     default_value: t.Optional[t.Any] = None
#    2192     allow_none = True
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in error(self, obj, value, error, info)
#     690         try:
#     691             old_value = obj._trait_values[self.name]
# --> 692         except KeyError:
#     693             old_value = self.default_value
#     694
#
# TraitError: The 'value' trait of a Label instance expected a unicode string, not the int 1.
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     754                 if 'buffer_paths' in data:
#     755                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 756                 self.set_state(state)
#     757
#     758         # Handle a state request.
#
# /usr/local/lib/python3.7/dist-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     623                     from_json = self.trait_metadata(name, 'from_json',
#     624                                                     self._trait_from_json)
# --> 625                     self.set_trait(name, from_json(sync_data[name], self))
#     626
#     627     def send(self, content, buffers=None):
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in set_trait(self, name, value)
#    1436             self._trait_notifiers[name] = {type: nlist}
#    1437         else:
# -> 1438             if type not in self._trait_notifiers[name]:
#    1439                 nlist = []
#    1440                 self._trait_notifiers[name][type] = nlist
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in set(self, obj, value)
#     578                 self.metadata = kwargs
#     579         else:
# --> 580             self.metadata = self.metadata.copy()
#     581         if config is not None:
#     582             self.metadata["config"] = config
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in _validate(self, obj, value)
#     610         This method is registered to HasTraits classes during ``class_init``
#     611         in the same way that dynamic defaults defined by ``@default`` are.
# --> 612         """
#     613         if self.default_value is not Undefined:
#     614             return self.default_value
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in validate(self, obj, value)
#    2188 class Any(TraitType):
#    2189     """A trait which allows any value."""
# -> 2190
#    2191     default_value: t.Optional[t.Any] = None
#    2192     allow_none = True
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in error(self, obj, value, error, info)
#     690         try:
#     691             old_value = obj._trait_values[self.name]
# --> 692         except KeyError:
#     693             old_value = self.default_value
#     694
#
# TraitError: The 'value' trait of a Label instance expected a unicode string, not the int 1984.
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     754                 if 'buffer_paths' in data:
#     755                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 756                 self.set_state(state)
#     757
#     758         # Handle a state request.
#
# /usr/local/lib/python3.7/dist-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     623                     from_json = self.trait_metadata(name, 'from_json',
#     624                                                     self._trait_from_json)
# --> 625                     self.set_trait(name, from_json(sync_data[name], self))
#     626
#     627     def send(self, content, buffers=None):
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in set_trait(self, name, value)
#    1436             self._trait_notifiers[name] = {type: nlist}
#    1437         else:
# -> 1438             if type not in self._trait_notifiers[name]:
#    1439                 nlist = []
#    1440                 self._trait_notifiers[name][type] = nlist
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in set(self, obj, value)
#     578                 self.metadata = kwargs
#     579         else:
# --> 580             self.metadata = self.metadata.copy()
#     581         if config is not None:
#     582             self.metadata["config"] = config
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in _validate(self, obj, value)
#     610         This method is registered to HasTraits classes during ``class_init``
#     611         in the same way that dynamic defaults defined by ``@default`` are.
# --> 612         """
#     613         if self.default_value is not Undefined:
#     614             return self.default_value
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in validate(self, obj, value)
#    2188 class Any(TraitType):
#    2189     """A trait which allows any value."""
# -> 2190
#    2191     default_value: t.Optional[t.Any] = None
#    2192     allow_none = True
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in error(self, obj, value, error, info)
#     690         try:
#     691             old_value = obj._trait_values[self.name]
# --> 692         except KeyError:
#     693             old_value = self.default_value
#     694
#
# TraitError: The 'value' trait of a Label instance expected a unicode string, not the int 2020.
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     754                 if 'buffer_paths' in data:
#     755                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 756                 self.set_state(state)
#     757
#     758         # Handle a state request.
#
# /usr/local/lib/python3.7/dist-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     623                     from_json = self.trait_metadata(name, 'from_json',
#     624                                                     self._trait_from_json)
# --> 625                     self.set_trait(name, from_json(sync_data[name], self))
#     626
#     627     def send(self, content, buffers=None):
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in set_trait(self, name, value)
#    1436             self._trait_notifiers[name] = {type: nlist}
#    1437         else:
# -> 1438             if type not in self._trait_notifiers[name]:
#    1439                 nlist = []
#    1440                 self._trait_notifiers[name][type] = nlist
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in set(self, obj, value)
#     578                 self.metadata = kwargs
#     579         else:
# --> 580             self.metadata = self.metadata.copy()
#     581         if config is not None:
#     582             self.metadata["config"] = config
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in _validate(self, obj, value)
#     610         This method is registered to HasTraits classes during ``class_init``
#     611         in the same way that dynamic defaults defined by ``@default`` are.
# --> 612         """
#     613         if self.default_value is not Undefined:
#     614             return self.default_value
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in validate(self, obj, value)
#    2188 class Any(TraitType):
#    2189     """A trait which allows any value."""
# -> 2190
#    2191     default_value: t.Optional[t.Any] = None
#    2192     allow_none = True
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in error(self, obj, value, error, info)
#     690         try:
#     691             old_value = obj._trait_values[self.name]
# --> 692         except KeyError:
#     693             old_value = self.default_value
#     694
#
# TraitError: The 'value' trait of a Label instance expected a unicode string, not the int 1.
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     754                 if 'buffer_paths' in data:
#     755                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 756                 self.set_state(state)
#     757
#     758         # Handle a state request.
#
# /usr/local/lib/python3.7/dist-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     623                     from_json = self.trait_metadata(name, 'from_json',
#     624                                                     self._trait_from_json)
# --> 625                     self.set_trait(name, from_json(sync_data[name], self))
#     626
#     627     def send(self, content, buffers=None):
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in set_trait(self, name, value)
#    1436             self._trait_notifiers[name] = {type: nlist}
#    1437         else:
# -> 1438             if type not in self._trait_notifiers[name]:
#    1439                 nlist = []
#    1440                 self._trait_notifiers[name][type] = nlist
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in set(self, obj, value)
#     578                 self.metadata = kwargs
#     579         else:
# --> 580             self.metadata = self.metadata.copy()
#     581         if config is not None:
#     582             self.metadata["config"] = config
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in _validate(self, obj, value)
#     610         This method is registered to HasTraits classes during ``class_init``
#     611         in the same way that dynamic defaults defined by ``@default`` are.
# --> 612         """
#     613         if self.default_value is not Undefined:
#     614             return self.default_value
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in validate(self, obj, value)
#    2188 class Any(TraitType):
#    2189     """A trait which allows any value."""
# -> 2190
#    2191     default_value: t.Optional[t.Any] = None
#    2192     allow_none = True
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in error(self, obj, value, error, info)
#     690         try:
#     691             old_value = obj._trait_values[self.name]
# --> 692         except KeyError:
#     693             old_value = self.default_value
#     694
#
# TraitError: The 'value' trait of a Label instance expected a unicode string, not the int 12.
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipywidgets/widgets/widget.py in _handle_msg(self, msg)
#     754                 if 'buffer_paths' in data:
#     755                     _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 756                 self.set_state(state)
#     757
#     758         # Handle a state request.
#
# /usr/local/lib/python3.7/dist-packages/ipywidgets/widgets/widget.py in set_state(self, sync_data)
#     623                     from_json = self.trait_metadata(name, 'from_json',
#     624                                                     self._trait_from_json)
# --> 625                     self.set_trait(name, from_json(sync_data[name], self))
#     626
#     627     def send(self, content, buffers=None):
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in set_trait(self, name, value)
#    1436             self._trait_notifiers[name] = {type: nlist}
#    1437         else:
# -> 1438             if type not in self._trait_notifiers[name]:
#    1439                 nlist = []
#    1440                 self._trait_notifiers[name][type] = nlist
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in set(self, obj, value)
#     578                 self.metadata = kwargs
#     579         else:
# --> 580             self.metadata = self.metadata.copy()
#     581         if config is not None:
#     582             self.metadata["config"] = config
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in _validate(self, obj, value)
#     610         This method is registered to HasTraits classes during ``class_init``
#     611         in the same way that dynamic defaults defined by ``@default`` are.
# --> 612         """
#     613         if self.default_value is not Undefined:
#     614             return self.default_value
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in validate(self, obj, value)
#    2188 class Any(TraitType):
#    2189     """A trait which allows any value."""
# -> 2190
#    2191     default_value: t.Optional[t.Any] = None
#    2192     allow_none = True
#
# /usr/local/lib/python3.7/dist-packages/traitlets/traitlets.py in error(self, obj, value, error, info)
#     690         try:
#     691             old_value = obj._trait_values[self.name]
# --> 692         except KeyError:
#     693             old_value = self.default_value
#     694
#
# TraitError: The 'value' trait of a Label instance expected a unicode string, not the float 1.0000000000000002.

# %% [markdown]
# ## Convert ee.FeatureCollection to Pandas DataFrame

# %%
countries_shp = '../data/countries.shp'
countries = geemap.shp_to_ee(countries_shp)
Map.addLayer(countries, {}, 'Countries')

# %%
df = geemap.ee_to_pandas(countries, selectors=['id', 'name'])
df.head()

# %% [markdown]
# ## Convert ee.FeatureCollection to GeoPandas GeoDataFrame

# %%
gdf = geemap.ee_to_geopandas(countries, selectors=['id', 'name'])
gdf.head()

# %% [markdown]
# ## Convert Pandas DataFrame to ee.FeatureCollection

# %%
in_csv = 'https://raw.githubusercontent.com/giswqs/data/main/world/world_cities.csv'

# %%
df = pd.read_csv(in_csv)
df.head()

# %%
fc = geemap.pandas_to_ee(df, latitude="latitude", longitude="longitude")

# %%
Map.addLayer(fc, {}, "pandas to ee")
Map

# %% [markdown]
# ## Convert GeoPandas GeoDataFrame to ee.FeatureCollection

# %%
gdf = gpd.read_file(
    "https://raw.githubusercontent.com/giswqs/data/main/us/us_states.geojson"
)
gdf.head()

# %%
fc = geemap.geopandas_to_ee(gdf)

# %%
Map.addLayer(fc, {}, "geopandas to ee")
Map
